# %%
adi = ["ad","dr"]
adi.extend('cde')
adi.extend(["adi"])
adi
# Out:
# ['ad', 'dr', 'c', 'd', 'e', 'adi']

# %%
username = input()
password = input()

if username == "admin" and password == "pass123":
    print("Login successfull")
else:
    print("login failed")
    print("invalid username or password")
# Out:
# Login successfull

# %%
# for finding total sum of numbers in list
numbers = [1,2,3,4,5]
total_sum = sum(numbers)
print(total_sum)
# Out:
# 15

# %%
fruits = ["apple", "banana", "orange", "mango", "grape", "pineapple", "strawberry", "watermelon", "pear", "peach", "kiwi", "papaya", "cherry", "blueberry", "pomegranate"]
count = -1
for ch in fruits:
    count += 1
    if ch == "grape":
        print("found")
        break
print(fruits[count])
print(fruits[count])
# Out:
# found
# grape
# grape
