# %%
str1 = "hi simply checking the length of string"
str2 = "aditya"
str3 = "LAKSHMAN"
str4 = "Chinnu"

# %%
print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))
# Out:
# 39
# 6
# 8
# 6

# %%
print(str1.upper())
print(str2.upper())
print(str3.lower())
print(str4.upper())
print(str4.lower())
# Out:
# HI SIMPLY CHECKING THE LENGTH OF STRING
# ADITYA
# lakshman
# CHINNU
# chinnu

# %%
pa ="madam"
pa1 = "adtiya"
if pa1 == pa1[::-1]:
    print ("pallindrome")
else:
    print("not pallindrome")
# Out:
# not pallindrome

# %%
str1 = str1.replace(' ','_')
print(str1)
# Out:
# hi_simply_checking_the_length_of_string

# %%
# revese a string
str5 = "new languages learning overhere"
new_word=str5[::-1]
print(new_word)
# Out:
# erehrevo gninrael segaugnal wen

# %%
name="           sentence "
remove_spaces=name.strip()
print(remove_spaces)
# Out:
# sentence

# %%
#Find a index of the first occurence of a character in a string
String="Learning python is simple and python is powerful"
char="p"
print(String.find(char))
# Out:
# 9

# %%
#count how many times a specific character appears in a string
String="Learning python is simple and python is powerful"
specific_character="s"
print(String.find(specific_character))
# Out:
# 17

# %%
#Split a sentense into a list of words
String="Learning python is simple and python is powerful"
print(String.split())
# Out:
# ['Learning', 'python', 'is', 'simple', 'and', 'python', 'is', 'powerful']

# %%
#Join a list of words into a single string with spaces
list=['Learning', 'python', 'is', 'simple', 'and', 'python', 'is', 'powerful']
print(' '.join(list))
# Out:
# Learning python is simple and python is powerful

# %%
#Replace a word in a sentence with another word
String="Learning python is simple and python is powerful"
print(String.replace("Learning","coding"))
# Out:
# coding python is simple and python is powerful
